# %%
import pandas as pd

# %%
def load_from_gspreadsheet(sheet_name, key):
    url = 'https://docs.google.com/spreadsheets/d/{key}/gviz/tq?tqx=out:csv&sheet={sheet_name}&headers=1'.format(
        key=key, sheet_name=sheet_name.replace(' ', '%20'))

    #log.info('Loading google spreadsheet from {}'.format(url))

    df = pd.read_csv(url)
    df.fillna('',inplace=True)
    return df

#df.drop([col for col in df.columns if col.startswith('Unnamed')], axis=1)

# %%
sheet_names = ["P1%20S","P2%20S","P3%20S","P4%20S","P5%20S","P6%20S","P7%20PRO"]
key = '1W9NXwkbNZImNyrRMwJUl0mwHb6UndEJ5q6QBHmoZY80'
slot_cols = ['Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
       'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
       'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
       'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
       'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
       'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
       'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60',
       'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64',
       'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68',
       'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72',
       'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75', 'Unnamed: 76',
       'Unnamed: 77', 'Unnamed: 78', 'Unnamed: 79', 'Unnamed: 80',
       'Unnamed: 81', 'Unnamed: 82', 'Unnamed: 83', 'Unnamed: 84',
       'Unnamed: 85']

seq_in = pd.DataFrame()
seq_out = pd.DataFrame()
for sheet_name in sheet_names:
    unnamed_cols = []
    test=load_from_gspreadsheet(sheet_name,key)
    for col in slot_cols:
        if col in list(test.columns):
            unnamed_cols.append(col)
            test[col] = test[col].astype(str)
    #print(unnamed_cols)
    seq_in.fillna('',inplace=True)
    seq_out.fillna('',inplace=True)
    seq_in = pd.concat([seq_in, test['Dialogue Act'].to_frame()], ignore_index=True)
    seq_out = pd.concat([seq_out,test[unnamed_cols]], ignore_index=True)
print(seq_out)
print(seq_in)
# Out:
#      Unnamed: 33                                Unnamed: 34 Unnamed: 35  \
# 0
# 1
# 2              0                                          0           0
# 3              0  B_Phase_of_Software_development_Lifecycle
# 4              0                                          0           0
# ...          ...                                        ...         ...
# 2241           0                                          0           0
# 2242           0                                          0           0
# 2243           0                                          0           0
# 2244           0                                          0           0
# 2245           0                                          0           0
#
#      Unnamed: 36 Unnamed: 37                                Unnamed: 38  \
# 0
# 1
# 2
# 3
# 4              0           0                                          0
# ...          ...         ...                                        ...
# ...

# %%
seq_out.to_csv(path_or_buf='./seq.out',sep=' ', index=False, header=False)
seq_in.to_csv(path_or_buf='./seq.in',sep=' ', index=False, header=False)

# %%
seq_out
